# %% [markdown]
# **BOX PLots of DATA SET**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
dataset_path = 'C:/Users/Roshan/Downloads/output_with_headers.csv'
df = pd.read_csv(dataset_path)

# Using one-hot encoding for categorical columns
# data = pd.get_dummies(data, columns=['Quality_Category'])
# data['Quality_Category'].fillna('High', inplace=1)
# data['Quality_Category'].fillna(Medium, inplace=2)
# data['Quality_Category'].fillna(Low, inplace=3)
import pandas as pd

# Assuming 'category_column' is the name of your column
# data = {'Quality_Category': ['High', 'Low', 'Medium']}
df = pd.DataFrame(df)
column_names = df.columns
print(column_names)

# Define a mapping dictionary
#category_mapping = {'Low': 1, 'Medium': 2, 'High': 3}

# Map the values in the 'category_column' using the mapping dictionary
#df['Quality_Category'] = df['Quality_Category'].map(category_mapping)
#cat = {'Red': 0, 'White': 1}
#df['Quality_Category']

# Print the DataFrame to see the result
print(df)

#print(df)

# Assuming 'data' is your dataset
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.title('Box Plot for Each Feature')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# Index(['Wife's age', 'Wife's education', 'Husband's education',
#        'Number of children ever born', 'Wife's religion',
#        'Wife's now working?', 'Husband's occupation',
#        'Standard-of-living index', 'Media exposure',
#        'Contraceptive method used'],
#       dtype='object')
#       Wife's age  Wife's education  Husband's education  \
# 0             24                 2                    3
# 1             45                 1                    3
# 2             43                 2                    3
# 3             42                 3                    2
# 4             36                 3                    3
# ...          ...               ...                  ...
# 1468          33                 4                    4
# 1469          33                 4                    4
# 1470          39                 3                    3
# 1471          33                 3                    3
# 1472          17                 3                    3
# ...

# %%
# Plot histograms for each feature
df.hist(figsize=(12, 10))
plt.suptitle('Histograms for Each Feature')
plt.show()

# %%
#df.drop('Wine_Type', axis=1, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Save the DataFrame to a CSV file
#df.to_csv('/content/drive/MyDrive/Neural Network Soft Computing Assignment/improved_dataset.csv', index=False)
X = df.drop('quality', axis=1)
y = df['quality']

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'X' is your feature matrix
# Create a MinMaxScaler object
scaler = StandardScaler()

# Fit and transform the data using the scaler
X_normalized = scaler.fit_transform(X)

# X_normalized is the normalized feature matrix
xy=(0.5, -0.2)
xytext=(0.5, -0.3)

# %%
print(X_normalized.shape)
# Out:
# (4898, 11)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=X_normalized)
plt.title('Box Plot for Each Feature')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Plot histograms for each feature
df.hist(figsize=(12, 10))
plt.suptitle('Histograms for Each Feature')
plt.show()
